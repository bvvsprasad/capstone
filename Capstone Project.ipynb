# %% [markdown]
# Note book for capstone project from the course Applied Data Sceince Capstone by IBM on Coursera

# %% [markdown]
# ##  Import libraries

# %% [markdown]
# lets first import the required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Simple Test

# %% [markdown]
# lets do simple test to validate our environment

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
